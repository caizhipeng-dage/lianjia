# %% [markdown]
# # 前言
# 本项目对厦门链家网在售的二手房数据进行分析，分析厦门的二手房价水平，数据来自 2020-9-22 厦门链家网爬虫结果，共有16219条数据，本项目将从房源数量、单价、总价、面积等几个角度来比较厦门各区域的情况，也会分析所有房源的房屋年限、装修情况、是否配备电梯、建筑类型、户型结构。在项目的最后，预算相对没那么多的情况下，给出了一些厦门岛内可选的房源，供参考选择。

# %%
# 导入常用库
from datetime import date,datetime
import matplotlib.pyplot as plt
# plt.style.use('fivethirtyeight')
import seaborn as sns
sns.set(style="ticks", color_codes=True)
import pyecharts as pe
import re
import numpy as np
import warnings
import pandas as pd
pd.set_option('display.max_columns', None)  # 显示所有列
# %matplotlib inline
plt.rcParams['font.sans-serif'] = ['SimHei']  # 图表可以显示中文
warnings.filterwarnings('ignore')
# Out:
# Bad key "text.kerning_factor" on line 4 in
# D:\Program Files (x86)\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %% [markdown]
# ## 数据概览

# %%
# 读取 Excel 数据
df = pd.read_excel(r"厦门链家网二手房爬虫数据_2020-09-22.xlsx",dtype={'房源编码':str})
df.head(3)
# Out:
#    Unnamed: 0                                               房源链接      总价 总价单位  \
# 0           0  https://xm.lianjia.com/ershoufang/105104628729...   660.0    万
# 1           1  https://xm.lianjia.com/ershoufang/105104643967...   789.7    万
# 2           2  https://xm.lianjia.com/ershoufang/105104685921...  1080.0    万
#
#           单价  小区名称 所在大区 所在详细区域      房屋户型        所在楼层     建筑面积 户型结构  套内面积 建筑类型  \
# 0  51985元/平米  玉成豪园   思明     莲前  3室1厅1厨2卫  低楼层 (共19层)  126.96㎡   平层  暂无数据   板楼
# 1  53000元/平米   海豚湾   思明   会展中心  3室2厅1厨2卫  低楼层 (共32层)     149㎡   错层  暂无数据   塔楼
# 2  80796元/平米  蓝湾国际   思明   体育中心  3室2厅1厨1卫  低楼层 (共31层)  133.67㎡   平层  暂无数据   板楼
#
#   房屋朝向  建筑结构 装修情况  梯户比例 配备电梯        挂牌时间 交易权属        上次交易  房屋用途  房屋年限 产权所属  \
# 0   东南  钢混结构   精装  两梯两户    有  2020-06-18  商品房  2020-06-20  普通住宅  未满两年   共有
# 1   东南  框架结构   精装  两梯两户    有  2020-06-20  商品房        暂无数据  普通住宅  暂无数据   共有
# 2   东南  钢混结构   精装  三梯三户    有  2020-06-26  商品房        暂无数据  普通住宅  暂无数据  非共有
#
#                                                 抵押信息     房本备件      房源编码 用水类型  \
# 0  \n                                有抵押 30万元 建设银...  已上传房本照片  00381041  NaN
# 1  \n                                无抵押\n       ...  未上传房本照片       NaN  NaN
# 2  \n                                无抵押\n       ...  未上传房本照片  00248646  NaN
#
#   用电类型 燃气价格 别墅类型
# 0  NaN  NaN  NaN
# 1  NaN  NaN  NaN
# 2  NaN  NaN  NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16219 entries, 0 to 16218
# Data columns (total 32 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  16219 non-null  int64
#  1   房源链接        16219 non-null  object
#  2   总价          16219 non-null  float64
#  3   总价单位        16219 non-null  object
#  4   单价          16219 non-null  object
#  5   小区名称        16219 non-null  object
#  6   所在大区        16219 non-null  object
#  7   所在详细区域      16218 non-null  object
#  8   房屋户型        15753 non-null  object
#  9   所在楼层        16219 non-null  object
#  10  建筑面积        16219 non-null  object
#  11  户型结构        15616 non-null  object
#  12  套内面积        15753 non-null  object
#  13  建筑类型        15616 non-null  object
#  14  房屋朝向        16219 non-null  object
#  15  建筑结构        15753 non-null  object
#  16  装修情况        15753 non-null  object
#  17  梯户比例        15616 non-null  object
#  18  配备电梯        15616 non-null  object
#  19  挂牌时间        16219 non-null  object
#  20  交易权属        16219 non-null  object
#  21  上次交易        16219 non-null  object
#  22  房屋用途        16219 non-null  object
#  23  房屋年限        16219 non-null  object
#  24  产权所属        16219 non-null  object
#  25  抵押信息        16219 non-null  object
#  26  房本备件        16219 non-null  object
#  27  房源编码        13408 non-null  object
#  28  用水类型        402 non-null    object
#  29  用电类型        402 non-null    object
#  30  燃气价格        86 non-null     object
#  31  别墅类型        104 non-null    object
# dtypes: float64(1), int64(1), object(30)
# memory usage: 4.0+ MB

# %% [markdown]
# 可以看出，很多列存在空值，后面需要处理。

# %%
df.describe()
# Out:
#          Unnamed: 0            总价
# count  16219.000000  16219.000000
# mean    8109.000000    385.523145
# std     4682.166343    295.233007
# min        0.000000     10.500000
# 25%     4054.500000    230.000000
# 50%     8109.000000    320.000000
# 75%    12163.500000    450.000000
# max    16218.000000   5200.000000

# %% [markdown]
# ## 数据清洗

# %% [markdown]
# ### 检查重复值

# %%
print(len(df[df.duplicated()])) # 查看重复值数量
# df.drop_duplicates(inplace=True)  # 删除重复值
# Out:
# 0

# %% [markdown]
# ### 筛选字段

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '房源链接', '总价', '总价单位', '单价', '小区名称', '所在大区', '所在详细区域',
#        '房屋户型', '所在楼层', '建筑面积', '户型结构', '套内面积', '建筑类型', '房屋朝向', '建筑结构', '装修情况',
#        '梯户比例', '配备电梯', '挂牌时间', '交易权属', '上次交易', '房屋用途', '房屋年限', '产权所属', '抵押信息',
#        '房本备件', '房源编码', '用水类型', '用电类型', '燃气价格', '别墅类型'],
#       dtype='object')

# %%
# 看一下总价单位是不是统一
df['总价单位'].value_counts()
# Out:
# 万    16219
# Name: 总价单位, dtype: int64

# %% [markdown]
# 住宅销售都是按照建筑面积计价，所以删除套内面积，保留建筑面积字段。

# %%
column_remain = ['总价', '单价', '小区名称', '所在大区', '所在详细区域', '房屋户型', '所在楼层', '建筑面积', '户型结构',
                 '建筑类型', '房屋朝向', '建筑结构', '装修情况', '梯户比例', '配备电梯', '挂牌时间', '交易权属', '上次交易',
                 '房屋用途', '房屋年限', '产权所属','房源编码']
df = df[column_remain]
df.head(3)
# Out:
#        总价         单价  小区名称 所在大区 所在详细区域      房屋户型        所在楼层     建筑面积 户型结构  \
# 0   660.0  51985元/平米  玉成豪园   思明     莲前  3室1厅1厨2卫  低楼层 (共19层)  126.96㎡   平层
# 1   789.7  53000元/平米   海豚湾   思明   会展中心  3室2厅1厨2卫  低楼层 (共32层)     149㎡   错层
# 2  1080.0  80796元/平米  蓝湾国际   思明   体育中心  3室2厅1厨1卫  低楼层 (共31层)  133.67㎡   平层
#
#   建筑类型 房屋朝向  建筑结构 装修情况  梯户比例 配备电梯        挂牌时间 交易权属        上次交易  房屋用途  房屋年限  \
# 0   板楼   东南  钢混结构   精装  两梯两户    有  2020-06-18  商品房  2020-06-20  普通住宅  未满两年
# 1   塔楼   东南  框架结构   精装  两梯两户    有  2020-06-20  商品房        暂无数据  普通住宅  暂无数据
# 2   板楼   东南  钢混结构   精装  三梯三户    有  2020-06-26  商品房        暂无数据  普通住宅  暂无数据
#
#   产权所属      房源编码
# 0   共有  00381041
# 1   共有       NaN
# 2  非共有  00248646

# %%
# 把暂无数据的值替换为空值，原先空值先不动
def drop_null(df, *columns):
    for column in columns:
        df[column][df[column] == '暂无数据'] = np.nan
#     return df

drop_null(df, '总价', '单价', '小区名称', '所在大区', '所在详细区域', '房屋户型', '所在楼层', '建筑面积', '户型结构',
          '建筑类型', '房屋朝向', '建筑结构', '装修情况', '梯户比例', '配备电梯', '挂牌时间', '交易权属', '上次交易',
          '房屋用途', '房屋年限', '产权所属')

# %% [markdown]
# ### 空值处理

# %% [markdown]
# - 配备电梯这列有空值，进行填充，采取的方法是，根据楼层来判断，一般的楼层大于6的都有电梯，而小于等于6层的一般都没有电梯，所以大于6层的空值填充为“有”，小于6层的空值填充为“无”。
# - 房屋户型、户型结构、建筑类型、建筑结构、装修情况、房屋年限，这几列空值，填充“缺失数据”，其他列空值不处理。

# %%
find = re.compile('\d{1,3}')
df['总楼层'] = df['所在楼层'].map(lambda x: find.findall(x)[0])
df['总楼层'] = df['总楼层'].astype(np.int64)
df.loc[(df['配备电梯'].isnull())&(df['总楼层']>6),'配备电梯']='有'
df.loc[(df['配备电梯'].isnull())&(df['总楼层']<=6),'配备电梯']='无'
df['配备电梯'].replace({'有':'有电梯','无':'无电梯'},inplace=True)
df['配备电梯'].value_counts()
# Out:
# 有电梯    12361
# 无电梯     3858
# Name: 配备电梯, dtype: int64

# %%
for column in ['房屋户型','户型结构','建筑类型','建筑结构','装修情况','房屋年限']:
    df[column].fillna('缺失数据', inplace=True)

# %% [markdown]
# ### 房屋用途清洗

# %%
df['房屋用途'].value_counts()
# Out:
# 普通住宅     15054
# 商业办公类      561
# 车库         466
# 别墅         137
# 平房           1
# Name: 房屋用途, dtype: int64

# %%
df[df['房屋用途']=='平房']
# Out:
#           总价         单价   小区名称 所在大区 所在详细区域      房屋户型       所在楼层     建筑面积 户型结构  \
# 1117  1800.0  79827元/平米  万科湖心岛   湖里   湖边水库  5室2厅1厨3卫  中楼层 (共5层)  225.49㎡   平层
#
#       建筑类型  房屋朝向  建筑结构 装修情况  梯户比例 配备电梯        挂牌时间 交易权属 上次交易 房屋用途  房屋年限 产权所属  \
# 1117  板塔结合  西南 西  钢混结构   毛坯  一梯四户  有电梯  2019-11-26  商品房  NaN   平房  缺失数据   共有
#
#           房源编码  总楼层
# 1117  00017967    5

# %%
df[df['小区名称']=='万科湖心岛']
# Out:
#            总价         单价   小区名称 所在大区 所在详细区域      房屋户型        所在楼层     建筑面积  \
# 1000   1980.0  77420元/平米  万科湖心岛   湖里   湖边水库  4室1厅1厨3卫  高楼层 (共31层)  255.75㎡
# 1117   1800.0  79827元/平米  万科湖心岛   湖里   湖边水库  5室2厅1厨3卫   中楼层 (共5层)  225.49㎡
# 1134   1935.0  75779元/平米  万科湖心岛   湖里   湖边水库  4室2厅1厨2卫  高楼层 (共27层)  255.35㎡
# 1357   2000.0  93897元/平米  万科湖心岛   湖里   湖边水库  5室2厅1厨5卫  低楼层 (共26层)     213㎡
# 10047  1680.0  65036元/平米  万科湖心岛   湖里   湖边水库  4室1厅1厨3卫   高楼层 (共4层)  258.32㎡
#
#        户型结构  建筑类型  房屋朝向  建筑结构 装修情况  梯户比例 配备电梯        挂牌时间 交易权属        上次交易  \
# 1000     平层    塔楼  西南 北  钢混结构   精装  两梯一户  有电梯  2019-07-10  商品房         NaN
# 1117     平层  板塔结合  西南 西  钢混结构   毛坯  一梯四户  有电梯  2019-11-26  商品房         NaN
# 1134     平层  板塔结合  西南 北  钢混结构   精装  两梯一户  有电梯  2020-06-23  商品房  2017-04-15
# 1357   缺失数据  缺失数据   南 北  钢混结构   精装   NaN  有电梯  2019-04-18  商品房         NaN
# 10047    平层  板塔结合  东南 北  钢混结构   精装  一梯一户  无电梯  2019-08-31  商品房  2017-03-15
#
#        房屋用途  房屋年限 产权所属      房源编码  总楼层
# 1000   普通住宅  缺失数据  非共有       NaN   31
# 1117     平房  缺失数据   共有  00017967    5
# 1134   普通住宅   满两年  非共有  00503785   27
# 1357     别墅  缺失数据  非共有  00164276   26
# 10047  普通住宅   满两年  非共有       NaN    4

# %%
df['房屋用途'][df['房屋用途']=='平房']='别墅'
df=df[[x in ['普通住宅','别墅'] for x in df['房屋用途']]]
df['房屋用途'].value_counts()
# Out:
# 普通住宅    15054
# 别墅        138
# Name: 房屋用途, dtype: int64

# %% [markdown]
# - 房屋用途的平房数据只有一条，怀疑数据录入有误，通过观察这条数据对应的小区名称，这条数据所在的楼层是5层，所以把这个房屋用途改为别墅。
# - 删除车库和商业办公类的房源，只保留普通住宅和别墅的数据

# %% [markdown]
# ### 房屋年限计算

# %%
# 转化为日期格式
df['挂牌时间'] = pd.to_datetime(df['挂牌时间'])
df['上次交易'] = pd.to_datetime(df['上次交易'])
df['房屋年限/年'] = df['挂牌时间']-df['上次交易']  # 得到的单位是：天
df['房屋年限/年'] = df['房屋年限/年'].map(lambda x: x.days)  # 去掉单位
df['房屋年限/年'] = df['房屋年限/年']/365  # 转化为年

# %% [markdown]
# ### 去掉单位，转换格式

# %%
df['单价']=df['单价'].str.replace('元/平米','')  # 去掉单位
df['单价']=df['单价'].astype(np.float64)  # 转化为浮点型

df['建筑面积']=df['建筑面积'].str.replace('㎡','')  # 去掉单位
df['建筑面积']=df['建筑面积'].astype(np.float64)  # 转化为浮点型

# %% [markdown]
# ### 数据概览

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15192 entries, 0 to 16217
# Data columns (total 24 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   总价      15192 non-null  float64
#  1   单价      15192 non-null  float64
#  2   小区名称    15192 non-null  object
#  3   所在大区    15192 non-null  object
#  4   所在详细区域  15191 non-null  object
#  5   房屋户型    15192 non-null  object
#  6   所在楼层    15192 non-null  object
#  7   建筑面积    15192 non-null  float64
#  8   户型结构    15192 non-null  object
#  9   建筑类型    15192 non-null  object
#  10  房屋朝向    15192 non-null  object
#  11  建筑结构    15192 non-null  object
#  12  装修情况    15192 non-null  object
#  13  梯户比例    15055 non-null  object
#  14  配备电梯    15192 non-null  object
#  15  挂牌时间    15192 non-null  datetime64[ns]
#  16  交易权属    15192 non-null  object
#  17  上次交易    6865 non-null   datetime64[ns]
#  18  房屋用途    15192 non-null  object
#  19  房屋年限    15192 non-null  object
#  20  产权所属    15164 non-null  object
#  21  房源编码    12577 non-null  object
#  22  总楼层     15192 non-null  int64
#  23  房屋年限/年  6865 non-null   float64
# dtypes: datetime64[ns](2), float64(4), int64(1), object(17)
# memory usage: 2.9+ MB

# %%
df.describe()
# Out:
#                  总价             单价          建筑面积           总楼层       房屋年限/年
# count  15192.000000   15192.000000  15192.000000  15192.000000  6865.000000
# mean     405.480003   39613.878884    101.426752     20.549039     5.555668
# std      293.110943   16618.042447     41.068197     11.812257     4.911818
# min       12.000000    3888.000000     12.720000      0.000000    -2.791781
# 25%      245.000000   27738.750000     80.000000      9.000000     2.205479
# 50%      330.000000   35326.000000     90.935000     18.000000     4.010959
# 75%      460.000000   48456.750000    122.000000     31.000000     7.947945
# max     5200.000000  150000.000000    698.120000     59.000000    35.969863

# %% [markdown]
# ## 数据分析及可视化

# %% [markdown]
# ### 二手房挂牌数量和时间的关系

# %%
df_time=df[['房源编码','挂牌时间']]
df_time.set_index('挂牌时间',inplace=True)
# 以月为单位重采样
df_time.resample('M').count().head()
# Out:
#             房源编码
# 挂牌时间
# 2015-11-30     1
# 2015-12-31     0
# 2016-01-31     0
# 2016-02-29     0
# 2016-03-31     0

# %%
# 绘制折线图
line = pe.Line('二手房数量挂牌时间分布', title_pos='center',width=1200,height=450)

attr_line = df_time.resample('M').count().index.strftime('%Y-%m').tolist()
v_line = df_time.resample('M').count()['房源编码'].values.tolist()

# is_label_show=True,显示数据标签;is_datazoom_show=True控制条，xaxis_interval=0,所有横坐标标签都显示,xaxis_rotate=60,标签旋转60度
line.add('', attr_line, v_line, is_label_show=False,
         is_datazoom_show=True, xaxis_interval=0, xaxis_rotate=60)
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="2878d7e38bd34849896286c35e8a86c3" style="width:1200px;height:450px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_2878d7e38bd34849896286c35e8a86c3 = echarts.init(document.getElementById('2878d7e38bd34849896286c35e8a86c3'), 'light', {renderer: 'canvas'});
#
# var option_2878d7e38bd34849896286c35e8a86c3 = {
#     "title": [
#         {
#             "text": "\u4e8c\u624b\u623f\u6570\u91cf\u6302\u724c\u65f6\u95f4\u5206\u5e03",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 2562295,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "2015-11",
#                     1
#                 ],
#                 [
#                     "2015-12",
#                     0
#                 ],
#                 [
#                     "2016-01",
#                     0
#                 ],
#                 [
#                     "2016-02",
#                     0
#                 ],
#                 [
#                     "2016-03",
#                     0
#                 ],
#                 [
#                     "2016-04",
#                     1
#                 ],
#                 [
#                     "2016-05",
#                     0
#                 ],
#                 [
#                     "2016-06",
#                     0
#                 ],
#                 [
#                     "2016-07",
#                     0
#                 ],
#                 [
#                     "2016-08",
#                     0
#                 ],
#                 [
#                     "2016-09",
#                     1
#                 ],
#                 [
#                     "2016-10",
#                     2
#                 ],
#                 [
#                     "2016-11",
#                     1
#                 ],
#                 [
#                     "2016-12",
#                     1
#                 ],
#                 [
#                     "2017-01",
#                     1
#                 ],
#                 [
#                     "2017-02",
#                     1
#                 ],
#                 [
#                     "2017-03",
#                     7
#                 ],
#                 [
#                     "2017-04",
#                     5
#                 ],
#                 [
#                     "2017-05",
#                     7
#                 ],
#                 [
#                     "2017-06",
#                     5
#                 ],
#                 [
#                     "2017-07",
#                     5
#                 ],
#                 [
#                     "2017-08",
#                     3
#                 ],
#                 [
#                     "2017-09",
#                     6
#                 ],
#                 [
#                     "2017-10",
#                     9
#                 ],
#                 [
#                     "2017-11",
#                     11
#                 ],
#                 [
#                     "2017-12",
#                     12
#                 ],
#                 [
#                     "2018-01",
#                     4
#                 ],
#                 [
#                     "2018-02",
#                     5
#                 ],
#                 [
#                     "2018-03",
#                     17
#                 ],
#                 [
#                     "2018-04",
#                     17
#                 ],
#                 [
#                     "2018-05",
#                     13
#                 ],
#                 [
#                     "2018-06",
#                     20
#                 ],
#                 [
#                     "2018-07",
#                     31
#                 ],
#                 [
#                     "2018-08",
#                     18
#                 ],
#                 [
#                     "2018-09",
#                     42
#                 ],
#                 [
#                     "2018-10",
#                     62
#                 ],
#                 [
#                     "2018-11",
#                     48
#                 ],
#                 [
#                     "2018-12",
#                     56
#                 ],
#                 [
#                     "2019-01",
#                     101
#                 ],
#                 [
#                     "2019-02",
#                     104
#                 ],
#                 [
#                     "2019-03",
#                     304
#                 ],
#                 [
#                     "2019-04",
#                     449
#                 ],
#                 [
#                     "2019-05",
#                     460
#                 ],
#                 [
#                     "2019-06",
#                     475
#                 ],
#                 [
#                     "2019-07",
#                     375
#                 ],
#                 [
#                     "2019-08",
#                     424
#                 ],
#                 [
#                     "2019-09",
#                     440
#                 ],
#                 [
#                     "2019-10",
#                     432
#                 ],
#                 [
#                     "2019-11",
#                     428
#                 ],
#                 [
#                     "2019-12",
#                     439
#                 ],
#                 [
#                     "2020-01",
#                     276
#                 ],
#                 [
#                     "2020-02",
#                     91
#                 ],
#                 [
#                     "2020-03",
#                     693
#                 ],
#                 [
#                     "2020-04",
#                     1065
#                 ],
#                 [
#                     "2020-05",
#                     1138
#                 ],
#                 [
#                     "2020-06",
#                     1183
#                 ],
#                 [
#                     "2020-07",
#                     1223
#                 ],
#                 [
#                     "2020-08",
#                     1338
#                 ],
#                 [
#                     "2020-09",
#                     727
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },

# %% [markdown]
# - 房源数量：2020年1月和2月，厦门二手房源数量下降明显，下降明显的原因应该是大环境疫情因素，3月开始，房源数量暴增，并且不断增加，8月达到顶峰，9月份开始回落，由于数据采集时间是9月22号，预计9月份在售房源数量在1000套左右；
# - 2015年和2016年的在售的房源数量都不多，并不能说明那时候二手房没有交易，更有可能的原因是2015年和2016年挂牌的房源大部分已经成交了，能看到的这些是还没有成交的房源。

# %% [markdown]
# ### 二手房数量对比

# %%
# 定义函数，将两个字典合并
def add_value(x, y, list_):
    '''
    x:字典
    y:字典
    list_:列表
    '''
    xm_dict = {}
    x_dict = x.to_dict()
    y_dict = y.to_dict()
    for i in list_:
        if i not in x_dict.keys():
            x_dict[i] = 0
        elif i not in y_dict.keys():
            y_dict[i] = 0
        xm_dict[i] = (x_dict[i], y_dict[i])
    return xm_dict

# %%
# 图表横坐标轴
x_axis = ['思明', '湖里', '集美', '海沧', '翔安', '同安']

# 绘制柱形图
bar1 = pe.Bar('厦门各区域二手房数量对比', height=400, width=700,title_pos='center')

# 按区域汇总普通住宅、别墅数量
house_count = df[df['房屋用途']=='普通住宅'].groupby(['所在大区'])['房源编码'].count()
house_count_villa = df[df['房屋用途']=='别墅'].groupby(['所在大区'])['房源编码'].count()

xm_count_dict = add_value(house_count,house_count_villa,x_axis)

# is_label_show=True,显示数据标签
bar1.add('普通住宅', [i for i in xm_count_dict.keys()], [i[0] for i in xm_count_dict.values()], is_label_show=True)
bar1.add('别墅', [i for i in xm_count_dict.keys()], [i[1] for i in xm_count_dict.values()], is_label_show=True,
        yaxis_name='数量', yaxis_name_gap=20, yaxis_name_pos='end',legend_top='7%')
bar1
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="fc1065f6b12e45d3a345bfc9db3a76e3" style="width:700px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_fc1065f6b12e45d3a345bfc9db3a76e3 = echarts.init(document.getElementById('fc1065f6b12e45d3a345bfc9db3a76e3'), 'light', {renderer: 'canvas'});
#
# var option_fc1065f6b12e45d3a345bfc9db3a76e3 = {
#     "title": [
#         {
#             "text": "\u53a6\u95e8\u5404\u533a\u57df\u4e8c\u624b\u623f\u6570\u91cf\u5bf9\u6bd4",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 8165492,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u666e\u901a\u4f4f\u5b85",
#             "data": [
#                 2260,
#                 2403,
#                 2498,
#                 2599,
#                 1713,
#                 993
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 8165492
#         },
#         {
#             "type": "bar",
#             "name": "\u522b\u5885",
#             "data": [
#                 4,
#                 3,
#                 0,
#                 5,
#                 52,
#                 47
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 8165492
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u666e\u901a\u4f4f\u5b85",
#                 "\u522b\u5885"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "7%",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u601d\u660e",
#                 "\u6e56\u91cc",
#                 "\u96c6\u7f8e",
#                 "\u6d77\u6ca7",
#                 "\u7fd4\u5b89",
#                 "\u540c\u5b89"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u6570\u91cf",
#             "show": true,
#             "nameLocation": "end",
#             "nameGap": 20,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_fc1065f6b12e45d3a345bfc9db3a76e3.setOption(option_fc1065f6b12e45d3a345bfc9db3a76e3);
#
#     });
# </script>

# %% [markdown]
# - 二手房数量：在这个数据集里，二手房源以普通住宅为主，思明湖里集美海沧是比较火热的区域，海沧的普通住宅房源数量最多，其次是集美，同安最少；思明湖里海沧的在售二手别墅数量都比较少，翔安和同安比较多，集美区域没有别墅。
# - 别墅数量不多，所以接下来分析价格的时候，不单独分析普通住宅和别墅。

# %% [markdown]
# ### 二手房单价分析

# %%
print('厦门房源均价是{:.1f}元/平米。'.format(df['单价'].mean()))
unit_30000=len(df[df['单价']<=30000])/len(df)
print('单价3万/平米以内的房源占比是{:.3f}。'.format(unit_30000))

# 绘制柱形图
bar2 = pe.Bar('厦门各区域二手房均价对比', height=400, width=700, title_pos='center')
# bar1.use_theme("dark")  # 使用暗色主题

# 按区域汇总房源均价
house_mean = df.groupby(['所在大区'])['单价'].mean()

bar2.add('', x_axis, [house_mean[i] for i in x_axis], is_label_show=False,
         yaxis_name='单价 元/平米', yaxis_name_gap=20, yaxis_name_pos='end', legend_top='7%')
bar2
# Out:
# 厦门房源均价是39613.9元/平米。
# 单价3万/平米以内的房源占比是0.331。
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="6f3d488561b849969579654a9ec6480c" style="width:700px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_6f3d488561b849969579654a9ec6480c = echarts.init(document.getElementById('6f3d488561b849969579654a9ec6480c'), 'light', {renderer: 'canvas'});
#
# var option_6f3d488561b849969579654a9ec6480c = {
#     "title": [
#         {
#             "text": "\u53a6\u95e8\u5404\u533a\u57df\u4e8c\u624b\u623f\u5747\u4ef7\u5bf9\u6bd4",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 4381522,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 57437.22319918837,
#                 52468.372852233675,
#                 31084.02601848682,
#                 33678.782837127845,
#                 26974.536842105263,
#                 24300.949566587864
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 4381522
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "7%",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u601d\u660e",
#                 "\u6e56\u91cc",
#                 "\u96c6\u7f8e",
#                 "\u6d77\u6ca7",
#                 "\u7fd4\u5b89",
#                 "\u540c\u5b89"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u5355\u4ef7 \u5143/\u5e73\u7c73",
#             "show": true,
#             "nameLocation": "end",
#             "nameGap": 20,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_6f3d488561b849969579654a9ec6480c.setOption(option_6f3d488561b849969579654a9ec6480c);
#
#     });
# </script>

# %% [markdown]
# - 二手房均价：厦门所有区域二手房均价为39613.9万/平米，其中思明区的均价最高，达到57437元/平米，其次是湖里区52468元/平米，集美海沧翔安同安的均价均低于4万/平米，翔安和同安在3万/平米以内。

# %%
# seaborn绘制箱型图
# sns.catplot(x="所在大区", y="单价", kind="box", data=df)

# %%
# 设置图表 y 轴
def get_y(str1,str2,str3):
    '''
    str1:房屋用途
    str2:房屋用途
    str3:统计类别
    '''
    y_axis1=[]
    y_axis2=[]
    for i in x_axis:
        unit1=df[df['房屋用途']==str1][df['所在大区'] == i][str3].values.tolist()
        unit2=df[df['房屋用途']==str2][df['所在大区'] == i][str3].values.tolist()
        if len(unit1)!=0:
            y_axis1.append(unit1)
        else:
            y_axis1.append([0,0,0,0])
        if len(unit2)!=0:
            y_axis2.append(unit2)
        else:
            y_axis2.append([0,0,0,0])
    return y_axis1,y_axis2

# %%
# 绘制箱型图
boxplot1 = pe.Boxplot('厦门各区域二手房单价分布情况', title_pos='center',height=400, width=700)

y_axis_unit=[]
for i in x_axis:
    y_axis_unit.append(df[df['所在大区'] == i]['单价'].values.tolist())

_yaxis2 = boxplot1.prepare_data(y_axis_unit)  

# 设置纵坐标轴名称和位置
boxplot1.add('', x_axis, _yaxis2,yaxis_name='单价 元/平米',yaxis_name_gap=20, yaxis_name_pos='end',is_label_show=True,legend_top='7%')
boxplot1
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="97d2051c05494b62acf0ef864df10307" style="width:700px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_97d2051c05494b62acf0ef864df10307 = echarts.init(document.getElementById('97d2051c05494b62acf0ef864df10307'), 'light', {renderer: 'canvas'});
#
# var option_97d2051c05494b62acf0ef864df10307 = {
#     "title": [
#         {
#             "text": "\u53a6\u95e8\u5404\u533a\u57df\u4e8c\u624b\u623f\u5355\u4ef7\u5206\u5e03\u60c5\u51b5",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 4057680,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "boxplot",
#             "data": [
#                 [
#                     20430.0,
#                     49107.5,
#                     55410.0,
#                     63664.0,
#                     141134.0
#                 ],
#                 [
#                     12976.0,
#                     40910.0,
#                     47404.0,
#                     58839.0,
#                     150000.0
#                 ],
#                 [
#                     13976.0,
#                     25109.5,
#                     30995.0,
#                     35820.5,
#                     74611.0
#                 ],
#                 [
#                     10658.0,
#                     29520.0,
#                     32259.0,
#                     37055.0,
#                     80113.0
#                 ],
#                 [
#                     3888.0,
#                     23927.75,
#                     26623.0,
#                     29355.5,
#                     78347.0
#                 ],
#                 [
#                     4600.0,
#                     18379.5,
#                     23067.0,
#                     29263.5,
#                     100298.0
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 4057680
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "7%",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u601d\u660e",
#                 "\u6e56\u91cc",
#                 "\u96c6\u7f8e",
#                 "\u6d77\u6ca7",
#                 "\u7fd4\u5b89",
#                 "\u540c\u5b89"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u5355\u4ef7 \u5143/\u5e73\u7c73",
#             "show": true,
#             "nameLocation": "end",
#             "nameGap": 20,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_97d2051c05494b62acf0ef864df10307.setOption(option_97d2051c05494b62acf0ef864df10307);
#
#     });
# </script>

# %%
# 查看单价5000元/平米以内的房源
df[df['单价']<5000]
# Out:
#         总价      单价      小区名称 所在大区 所在详细区域      房屋户型       所在楼层   建筑面积  户型结构  \
# 8306  16.0  4366.0    美地雅登二里   翔安     新店  1室0厅0厨0卫  地下室 (共0层)  36.65  缺失数据
# 8569  12.0  3888.0  国贸金门湾朗琴园   翔安    大嶝岛  1室0厅0厨0卫  地下室 (共0层)  30.87  缺失数据
# 9638  23.8  4600.0      长荣花园   同安   集美其它  1室0厅0厨0卫  地下室 (共0层)  51.74  缺失数据
#
#       建筑类型 房屋朝向  建筑结构 装修情况   梯户比例 配备电梯       挂牌时间 交易权属 上次交易  房屋用途  房屋年限 产权所属  \
# 8306    板楼  南 北  钢混结构   毛坯  两梯十七户  有电梯 2019-08-01  商品房  NaT  普通住宅  缺失数据  非共有
# 8569  缺失数据    东  未知结构   简装   一梯一户  无电梯 2020-04-29  商品房  NaT  普通住宅  缺失数据  非共有
# 9638  缺失数据   东南  未知结构   其他   一梯一户  无电梯 2020-08-01  商品房  NaT  普通住宅  缺失数据  非共有
#
#           房源编码  总楼层  房屋年限/年
# 8306  00433923    0     NaN
# 8569  00251429    0     NaN
# 9638  00496003    0     NaN

# %%
# 查看单价150000元/平米以内的房源
df[df['单价']==df['单价'].max()]
# Out:
#            总价        单价     小区名称 所在大区 所在详细区域      房屋户型        所在楼层    建筑面积  \
# 14879  3697.8  150000.0  国贸天琴湾一期   湖里    五缘湾  4室2厅1厨3卫  中楼层 (共34层)  246.52
#
#       户型结构 建筑类型  房屋朝向  建筑结构 装修情况  梯户比例 配备电梯       挂牌时间 交易权属 上次交易  房屋用途  房屋年限  \
# 14879   平层   板楼  东南 北  钢混结构   精装  三梯两户  有电梯 2020-01-08  商品房  NaT  普通住宅  缺失数据
#
#       产权所属      房源编码  总楼层  房屋年限/年
# 14879  非共有  00519347   34     NaN

# %% [markdown]
# - 二手房单价：3万/平米是比较明显的价格分界点，厦门单价3万/平米以内的房源占比是33.1%，思明和湖里有超过 75% 的房源单价都在3万/平米以上，两个区域只有部分房源在3万/平米以内，毕竟岛内是寸土寸金的地方，集美有超过一半的房源单价在3万/平米以内，海沧有25%左右的房源单价是3万/平米以内的，翔安和同安都有超过75%的房源单价是3万/平米以内的；单价最高的房源在湖里，达到了15万/平米，单价最低的房源在翔安，为3888元/平米，价格相差38倍，可以说差距非常巨大。
# - 单价在5000元/平米以内的房源有3个，分别是翔安的美地雅登二里、国贸金门湾朗琴园，同安的长荣花园；单价最高的是湖里的国贸天琴湾一期，单价是15万/平米。

# %% [markdown]
# ### 二手房总价分析

# %%
print('厦门二手房总价平均值是{:.0f}万。'.format(df['总价'].mean()))
total_500=len(df[df['总价']<=500])/len(df)
total_300=len(df[df['总价']<=300])/len(df)
print('总价500万以内的房源占比是{:.3f}。'.format(total_500))
print('总价300万以内的房源占比是{:.3f}。'.format(total_300))

# 绘制箱型图
boxplot2 = pe.Boxplot('厦门各区域二手房总价分布情况', title_pos='center',height=500, width=700)

# 设置图表 y 轴
y_axis_total=[]
for i in x_axis:
    y_axis_total.append(df[df['所在大区'] == i]['总价'].values.tolist())
_yaxis1 = boxplot2.prepare_data(y_axis_total)

# 设置纵坐标轴名称和位置，y轴间隔设置成500
boxplot2.add('', x_axis, _yaxis1,yaxis_name='总价 /万',yaxis_name_gap=20, yaxis_name_pos='end',yaxis_force_interval=500,legend_top='7%')
boxplot2
# Out:
# 厦门二手房总价平均值是405万。
# 总价500万以内的房源占比是0.797
# 总价300万以内的房源占比是0.419
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="c67b937ad20a4eaf80b75817a94b7ad1" style="width:700px;height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_c67b937ad20a4eaf80b75817a94b7ad1 = echarts.init(document.getElementById('c67b937ad20a4eaf80b75817a94b7ad1'), 'light', {renderer: 'canvas'});
#
# var option_c67b937ad20a4eaf80b75817a94b7ad1 = {
#     "title": [
#         {
#             "text": "\u53a6\u95e8\u5404\u533a\u57df\u4e8c\u624b\u623f\u603b\u4ef7\u5206\u5e03\u60c5\u51b5",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 943265,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "boxplot",
#             "data": [
#                 [
#                     95.0,
#                     358.0,
#                     430.0,
#                     570.0,
#                     2980.0
#                 ],
#                 [
#                     106.5,
#                     310.0,
#                     470.0,
#                     708.25,
#                     5200.0
#                 ],
#                 [
#                     65.0,
#                     230.0,
#                     289.0,
#                     375.0,
#                     1750.0
#                 ],
#                 [
#                     36.6,
#                     260.0,
#                     336.0,
#                     428.0,
#                     1650.0
#                 ],
#                 [
#                     12.0,
#                     205.0,
#                     245.0,
#                     310.0,
#                     2400.0
#                 ],
#                 [
#                     17.0,
#                     170.0,
#                     218.0,
#                     310.0,
#                     2800.0
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 943265
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "7%",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u601d\u660e",
#                 "\u6e56\u91cc",
#                 "\u96c6\u7f8e",
#                 "\u6d77\u6ca7",
#                 "\u7fd4\u5b89",
#                 "\u540c\u5b89"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u603b\u4ef7 /\u4e07",
#             "show": true,
#             "nameLocation": "end",
#             "nameGap": 20,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "interval": 500
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_c67b937ad20a4eaf80b75817a94b7ad1.setOption(option_c67b937ad20a4eaf80b75817a94b7ad1);
#
#     });
# </script>

# %%
# 查看总价50万以内的小区名称
df[df['总价']<50]['小区名称'].tolist()
# Out:
# ['海西·轻公寓',
#  '海西·轻公寓',
#  '海西·轻公寓',
#  '海西·轻公寓',
#  '海西·轻公寓',
#  '海西·轻公寓',
#  '泰禾红门',
#  '美地雅登二里',
#  '国贸金门湾朗琴园',
#  '世茂御海墅',
#  '中海万锦熙岸',
#  '长荣花园',
#  '美地雅登五里']

# %%
# 查看总价最高的房源
df[df['总价']==df['总价'].max()]
# Out:
#           总价        单价     小区名称 所在大区 所在详细区域      房屋户型        所在楼层    建筑面积  \
# 1503  5200.0  148985.0     建发央座   湖里    五缘湾  5室2厅2厨4卫  低楼层 (共28层)  349.03
# 1505  5200.0  135343.0  国贸天琴湾一期   湖里    五缘湾  5室2厅1厨5卫  低楼层 (共33层)  384.21
#
#      户型结构 建筑类型   房屋朝向  建筑结构 装修情况  梯户比例 配备电梯       挂牌时间 交易权属       上次交易  房屋用途  \
# 1503   平层   板楼    南 北  钢混结构   精装  三梯两户  有电梯 2019-08-27  商品房 2019-10-23  普通住宅
# 1505   平层   板楼  东 南 北  钢混结构   精装  三梯两户  有电梯 2019-09-18  商品房        NaT  普通住宅
#
#       房屋年限 产权所属        房源编码  总楼层    房屋年限/年
# 1503  未满两年  非共有  00416811\t   28 -0.156164
# 1505  缺失数据   共有         NaN   33       NaN

# %% [markdown]
# - 二手房总价：大部分的二手房总价在500万以内，集美海沧翔安同安有超过75%的房源总价在500万以内，每个区价格最高的房源价格都超过了1500万；
# - 总价最高的房源位于湖里区的建发央座和国贸天琴湾一期，总价达到5200万；总共有13个房源总价是50万以内的。

# %% [markdown]
# ### 二手房面积分析

# %%
area_100=len(df[df['建筑面积']<=100])/len(df)
print('面积小于等于100的房源占比是{:.3f}。'.format(area_100))

# 绘制箱型图
boxplot3 = pe.Boxplot('厦门各区域二手房面积分布情况', title_pos='center',height=400, width=700)

# 设置图表 y 轴
area=[]
for i in x_axis:
    area.append(df[df['所在大区'] == i]['建筑面积'].values.tolist())
_yaxis3 = boxplot3.prepare_data(area)

# 设置纵坐标轴名称和位置
boxplot3.add('', x_axis, _yaxis3, yaxis_name='面积 ㎡',yaxis_name_gap=20, yaxis_name_pos='end',legend_top='7%')
boxplot3
# Out:
# 面积小于等于100的房源占比是0.598
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="d53c8c9987bb4d988007aa60d70234b9" style="width:700px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_d53c8c9987bb4d988007aa60d70234b9 = echarts.init(document.getElementById('d53c8c9987bb4d988007aa60d70234b9'), 'light', {renderer: 'canvas'});
#
# var option_d53c8c9987bb4d988007aa60d70234b9 = {
#     "title": [
#         {
#             "text": "\u53a6\u95e8\u5404\u533a\u57df\u4e8c\u624b\u623f\u9762\u79ef\u5206\u5e03\u60c5\u51b5",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 7305332,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "boxplot",
#             "data": [
#                 [
#                     22.15,
#                     68.015,
#                     81.67,
#                     95.0,
#                     525.73
#                 ],
#                 [
#                     23.52,
#                     74.16499999999999,
#                     100.495,
#                     133.385,
#                     502.3
#                 ],
#                 [
#                     30.0,
#                     86.12,
#                     91.09,
#                     117.035,
#                     429.33
#                 ],
#                 [
#                     21.95,
#                     86.55,
#                     102.7,
#                     127.41,
#                     294.13
#                 ],
#                 [
#                     19.93,
#                     82.3825,
#                     89.57,
#                     117.9625,
#                     385.0
#                 ],
#                 [
#                     12.72,
#                     82.30000000000001,
#                     95.63,
#                     129.51999999999998,
#                     698.12
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 7305332
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "7%",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u601d\u660e",
#                 "\u6e56\u91cc",
#                 "\u96c6\u7f8e",
#                 "\u6d77\u6ca7",
#                 "\u7fd4\u5b89",
#                 "\u540c\u5b89"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u9762\u79ef \u33a1",
#             "show": true,
#             "nameLocation": "end",
#             "nameGap": 20,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_d53c8c9987bb4d988007aa60d70234b9.setOption(option_d53c8c9987bb4d988007aa60d70234b9);
#
#     });
# </script>

# %%
# 查看建筑面积最大的房源
df[df['建筑面积']==df['建筑面积'].max()]
# Out:
#           总价       单价    小区名称 所在大区 所在详细区域      房屋户型        所在楼层    建筑面积 户型结构  \
# 9399  2584.0  37014.0  金都海尚国际   同安   环东海域  6室3厅2厨5卫  高楼层 (共34层)  698.12   复式
#
#       建筑类型 房屋朝向  建筑结构 装修情况  梯户比例 配备电梯       挂牌时间 交易权属       上次交易  房屋用途  房屋年限  \
# 9399  板塔结合    南  钢混结构   毛坯  三梯三户  有电梯 2020-08-11  商品房 2019-04-08  普通住宅  未满两年
#
#      产权所属      房源编码  总楼层    房屋年限/年
# 9399  非共有  00494149   34  1.345205

# %%
# 查看建筑面积最小的房源
df[df['建筑面积']==df['建筑面积'].min()]
# Out:
#         总价       单价    小区名称 所在大区 所在详细区域      房屋户型       所在楼层   建筑面积  户型结构  \
# 9600  17.0  13365.0  中海万锦熙岸   同安   集美其它  1室0厅1厨1卫  地下室 (共0层)  12.72  缺失数据
#
#       建筑类型 房屋朝向  建筑结构 装修情况    梯户比例 配备电梯       挂牌时间 交易权属 上次交易  房屋用途  房屋年限 产权所属  \
# 9600  缺失数据   东南  钢混结构   简装  十九梯十七户  有电梯 2019-09-26  商品房  NaT  普通住宅  缺失数据  非共有
#
#           房源编码  总楼层  房屋年限/年
# 9600  00421805    0     NaN

# %%
# 查看思明区面积最大的房源
df[df['所在大区']=='思明'][df['建筑面积']==525.73]
# Out:
#          总价       单价    小区名称 所在大区 所在详细区域      房屋户型        所在楼层    建筑面积 户型结构  \
# 341  2800.0  53260.0  大西洋海景城   思明     思北  7室3厅1厨4卫  高楼层 (共27层)  525.73   复式
#
#      建筑类型   房屋朝向  建筑结构 装修情况  梯户比例 配备电梯       挂牌时间 交易权属 上次交易  房屋用途  房屋年限 产权所属  \
# 341  板塔结合  东南 西南  钢混结构   精装  三梯八户  有电梯 2020-06-28  商品房  NaT  普通住宅  缺失数据  非共有
#
#          房源编码  总楼层  房屋年限/年
# 341  00394415   27     NaN

# %% [markdown]
# - 二手房面积：100平米是一个分界点，所有区域面积小于等于100平米的房源占比是59.8%，，图中可以看出，思明75%的房源面积在100平米以内，湖里和海沧有一半左右房源面积在100平米以内，集美翔安同安3个区域，100平米以内的房源数量，均超过一半。
# - 面积最大和最小的房源都出现在同安，分别是金都海尚国际，面积698平米，以及中海万锦熙岸，面积12.7平米。思明区面积最大的房源是大西洋海景城，面积为525.73平米。

# %% [markdown]
# ### 二手房面积回归分析

# %%
f,[ax1,ax2] = plt.subplots(1,2,figsize = (20,10))

# 建房时间的分布情况
sns.distplot(df['建筑面积'],bins = 20,ax = ax1,color = 'r')
sns.kdeplot(df['建筑面积'],shade = True,ax = ax1)

# 建房时间和出售价格的关系
sns.regplot(x = '建筑面积',y = '总价',data = df,ax =ax2)

# %% [markdown]
# - 通过 distplot 和 kdeplot 绘制柱状图观察面积特征的分布情况，属于长尾分布，跟箱型图对比，可以发现很多房源面积很大，超出大部分房源。
# - 通过总价和面积的散点图，可以发现，总价和面积基本上呈现线性关系，即面积越大，总价越高，符合常识，图中没有发现异常点。

# %% [markdown]
# ### 房屋年限分析

# %%
df['房屋年限'].value_counts().sort_values()
# Out:
# 未满两年     907
# 满两年     2821
# 满五年     3119
# 缺失数据    8345
# Name: 房屋年限, dtype: int64

# %%
pie1 = pe.Pie('房屋年限分布',title_pos='center')

attr = df['房屋年限'].value_counts().sort_values().index.tolist()
v = df['房屋年限'].value_counts().sort_values().values.tolist()

pie1.add('', attr, v, is_label_show=True,is_legend_show=False)
pie1
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="717bb5fc98124c15bc4c62236294b447" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_717bb5fc98124c15bc4c62236294b447 = echarts.init(document.getElementById('717bb5fc98124c15bc4c62236294b447'), 'light', {renderer: 'canvas'});
#
# var option_717bb5fc98124c15bc4c62236294b447 = {
#     "title": [
#         {
#             "text": "\u623f\u5c4b\u5e74\u9650\u5206\u5e03",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 1413965,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "\u672a\u6ee1\u4e24\u5e74",
#                     "value": 907
#                 },
#                 {
#                     "name": "\u6ee1\u4e24\u5e74",
#                     "value": 2821
#                 },
#                 {
#                     "name": "\u6ee1\u4e94\u5e74",
#                     "value": 3119
#                 },
#                 {
#                     "name": "\u7f3a\u5931\u6570\u636e",
#                     "value": 8345
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 1413965
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u672a\u6ee1\u4e24\u5e74",
#                 "\u6ee1\u4e24\u5e74",
#                 "\u6ee1\u4e94\u5e74",
#                 "\u7f3a\u5931\u6570\u636e"
#             ],
#             "selectedMode": "multiple",
#             "show": false,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_717bb5fc98124c15bc4c62236294b447.setOption(option_717bb5fc98124c15bc4c62236294b447);
#
#     });
# </script>

# %% [markdown]
# - 房屋年限情况：房屋年限满2年的房源跟满5年的房源数量比较接近，但是都比未满两年的房源多很多，差距达到3倍。
# - 通过查资料，可以得知，满2年和满5年是指从购买房屋过户缴纳了契税的时间为准，至今的时间间隔已经满2年和满5年；对于卖房者来说，出售不满2年的住房，需要缴纳契税、中介费、个人所得税、5.6%的普通住宅增值税；满2年的住房免征5.6%的增值税；满5年的住房免征5.65%的增值税和个人所得税。因此对于卖房者来说，出售满2年的住房，缴纳的税费更低。这或许可以解释未满2年的房源比满2年和满5年的房源少得多的原因。

# %%
year=df['房屋年限/年'][df['房屋年限/年'].notnull()]
year.hist(bins=34,figsize=(15,10))

# %%
df[df['房屋年限/年']<0].shape
# Out:
# (415, 24)

# %%
year.min()
# Out:
# -2.791780821917808

# %% [markdown]
# ### 房屋户型分析

# %%
df['房屋户型'].value_counts()
# Out:
# 3室2厅1厨2卫    3294
# 2室2厅1厨1卫    2814
# 2室1厅1厨1卫    2210
# 3室2厅1厨1卫    1828
# 4室2厅1厨2卫    1369
#             ...
# 3室1厅1厨0卫       1
# 9室3厅1厨7卫       1
# 8室4厅2厨4卫       1
# 3室2厅2厨4卫       1
# 6室2厅1厨1卫       1
# Name: 房屋户型, Length: 156, dtype: int64

# %%
##条形图纵坐标轴无法显示标签
# bar=pe.Bar('房屋户型',title_pos='center',height=900, width=500,)

# attr=df['房屋户型'].value_counts().index.tolist()
# y=df['房屋户型'].value_counts().values.tolist()

# bar.add('',attr,y,is_convert=True,is_legend_show=False)
# bar

# %%
f,ax1 = plt.subplots(figsize = (20,40))
sns.countplot(y = '房屋户型',data = df,ax = ax1)
ax1.set_title('房屋户型分布',fontsize=25)
ax1.set_xlabel('数量')
ax1.set_ylabel('户型')
# Out:
# Text(0, 0.5, '户型')

# %%
df[df['房屋户型']=='14室1厅1厨9卫']
# Out:
#            总价       单价    小区名称 所在大区 所在详细区域       房屋户型       所在楼层   建筑面积  户型结构  \
# 10908  2580.0  57487.0  鼓浪屿龙头路   思明    鼓浪屿  14室1厅1厨9卫  低楼层 (共1层)  448.8  缺失数据
#
#        建筑类型   房屋朝向  建筑结构 装修情况 梯户比例 配备电梯       挂牌时间 交易权属 上次交易 房屋用途  房屋年限 产权所属  \
# 10908  缺失数据  东南 西北  未知结构   精装  NaN  无电梯 2020-09-07  商品房  NaT   别墅  缺失数据   共有
#
#       房源编码  总楼层  房屋年限/年
# 10908  NaN    1     NaN

# %% [markdown]
# - 房屋户型分布：可以看出2室和3室的房源比较多，3室2厅最多，然后是2室2厅，竟然有14室1厅1厨9卫的户型，是位于鼓浪屿的别墅

# %% [markdown]
# ### 户型结构、装修情况分析

# %%
df['户型结构'].value_counts()
# Out:
# 平层      13234
# 复式        864
# 缺失数据      710
# 错层        215
# 跃层        169
# Name: 户型结构, dtype: int64

# %%
x1 = df.groupby('装修情况')['房源编码'].count().index.tolist()
y1 = df.groupby('装修情况')['房源编码'].count().values.tolist()

x2 = df.groupby('户型结构')['房源编码'].count().index.tolist()
y2 = df.groupby('户型结构')['房源编码'].count().values.tolist()

pie2 = pe.Pie('二手房装修情况、户型结构分析', title_pos='center',width=1000)
pie2.add('', x1, y1, center=[30, 55],is_label_show=True)
pie2.add('', x2, y2, center=[70, 55],is_label_show=True,is_legend_show=False)
pie2
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="38cbc5162d5046da9f87c458dd6f716d" style="width:1000px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_38cbc5162d5046da9f87c458dd6f716d = echarts.init(document.getElementById('38cbc5162d5046da9f87c458dd6f716d'), 'light', {renderer: 'canvas'});
#
# var option_38cbc5162d5046da9f87c458dd6f716d = {
#     "title": [
#         {
#             "text": "\u4e8c\u624b\u623f\u88c5\u4fee\u60c5\u51b5\u3001\u6237\u578b\u7ed3\u6784\u5206\u6790",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 8116726,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "\u5176\u4ed6",
#                     "value": 60
#                 },
#                 {
#                     "name": "\u6bdb\u576f",
#                     "value": 1700
#                 },
#                 {
#                     "name": "\u7b80\u88c5",
#                     "value": 3734
#                 },
#                 {
#                     "name": "\u7cbe\u88c5",
#                     "value": 7083
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "30%",
#                 "55%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 8116726
#         },
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "\u590d\u5f0f",
#                     "value": 736
#                 },
#                 {
#                     "name": "\u5e73\u5c42",
#                     "value": 10962
#                 },
#                 {
#                     "name": "\u7f3a\u5931\u6570\u636e",
#                     "value": 563
#                 },
#                 {
#                     "name": "\u8dc3\u5c42",
#                     "value": 132
#                 },
#                 {
#                     "name": "\u9519\u5c42",
#                     "value": 184
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "70%",
#                 "55%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 8116726
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5176\u4ed6",
#                 "\u6bdb\u576f",
#                 "\u7b80\u88c5",
#                 "\u7cbe\u88c5",
#                 "\u590d\u5f0f",
#                 "\u5e73\u5c42",
#                 "\u7f3a\u5931\u6570\u636e",
#                 "\u8dc3\u5c42",
#                 "\u9519\u5c42"
#             ],
#             "selectedMode": "multiple",
#             "show": false,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_38cbc5162d5046da9f87c458dd6f716d.setOption(option_38cbc5162d5046da9f87c458dd6f716d);
#
#     });
# </script>

# %% [markdown]
# - 二手房装修情况：可以看出，在售房源有 56.32% 都是精装修的，超过一半；未装修的毛坯房占比13.51%；
# - 二手房户型结构情况：超过90%的房源是平层的户型结构，错层和跃层的比例都比较低。

# %% [markdown]
# ### 建筑类型、配备电梯情况分析

# %%
x3=df['建筑类型'].value_counts().index.tolist()
y3=df['建筑类型'].value_counts().values.tolist()

x4=df['配备电梯'].value_counts().index.tolist()
y4=df['配备电梯'].value_counts().values.tolist()

pie3 = pe.Pie('二手房建筑类型、配备电梯情况分析', title_pos='center',width=1000)
pie3.add('', x3, y3, center=[30, 55],is_label_show=True)
pie3.add('', x4, y4, center=[70, 55],is_label_show=True,is_legend_show=False)
pie3
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="d4f98696bd3b4fbfabaa690d38ed2726" style="width:1000px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_d4f98696bd3b4fbfabaa690d38ed2726 = echarts.init(document.getElementById('d4f98696bd3b4fbfabaa690d38ed2726'), 'light', {renderer: 'canvas'});
#
# var option_d4f98696bd3b4fbfabaa690d38ed2726 = {
#     "title": [
#         {
#             "text": "\u4e8c\u624b\u623f\u5efa\u7b51\u7c7b\u578b\u3001\u914d\u5907\u7535\u68af\u60c5\u51b5\u5206\u6790",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 3854660,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "\u677f\u697c",
#                     "value": 7676
#                 },
#                 {
#                     "name": "\u5854\u697c",
#                     "value": 3611
#                 },
#                 {
#                     "name": "\u677f\u5854\u7ed3\u5408",
#                     "value": 3261
#                 },
#                 {
#                     "name": "\u7f3a\u5931\u6570\u636e",
#                     "value": 567
#                 },
#                 {
#                     "name": "\u5e73\u623f",
#                     "value": 77
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "30%",
#                 "55%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 3854660
#         },
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "\u6709\u7535\u68af",
#                     "value": 11802
#                 },
#                 {
#                     "name": "\u65e0\u7535\u68af",
#                     "value": 3390
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "70%",
#                 "55%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 3854660
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u677f\u697c",
#                 "\u5854\u697c",
#                 "\u677f\u5854\u7ed3\u5408",
#                 "\u7f3a\u5931\u6570\u636e",
#                 "\u5e73\u623f",
#                 "\u6709\u7535\u68af",
#                 "\u65e0\u7535\u68af"
#             ],
#             "selectedMode": "multiple",
#             "show": false,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_d4f98696bd3b4fbfabaa690d38ed2726.setOption(option_d4f98696bd3b4fbfabaa690d38ed2726);
#
#     });
# </script>

# %% [markdown]
# - 建筑类型情况：超过一半房源的建筑类型是板楼，是塔楼数量的2倍。塔楼和板楼各有优缺点，板楼采光通风好，户型格局不宜改造，价格高；塔楼价格低，结构强度高，但是居住密度高。
# - 配备电梯情况：79.17%的房源都配备电梯，是无电梯房源的接近4倍，可以得出结论，房源里以高层住宅（>=6层）为主。

# %%
# 将多个图表显示在一个网页内
page = pe.Page()
page.add(line)
page.add(bar1)
page.add(bar2)
page.add(boxplot1)
page.add(boxplot2)
page.add(boxplot3)
page.add(pie1)
page.add(pie2)
page.add(pie3)
page.render('二手房项目图表.html') # 保存为本地 html 文件

# %% [markdown]
# ### 单价、区域、配备电梯、装修情况综合分析

# %%
grid = sns.FacetGrid(df,row = '配备电梯',col = '装修情况',palette = 'seismic',size = 4)
grid.map(plt.scatter,'所在大区','单价')
grid.add_legend()

# %% [markdown]
# - 综合分析：可以看出，同样的区域，有电梯的房源跟无电梯的房源相比，价格普遍比较高；

# %% [markdown]
# ## 买房参考

# %% [markdown]
# ### 湖里区单价3万/平米以内的房源小区名称（小区里面的部分房源）

# %%
print(list(set(df[(df['所在大区']=='湖里')&(df['单价']<30000)]['小区名称'].values.tolist())))
# Out:
# ['嘉福花园', '深汇大厦', '象屿大厦', '宏益华府', '都市雅苑', '怡景花园', '大唐五缘yoho', '民兴商城', '空港·云立方', '海丝艺术品中心', '韵园公寓', '和悦里', '天宇花园北区', '榕海花园', '芙蓉苑一期']

# %% [markdown]
# ### 湖里区总价200万以内的房源小区名称（小区里面的部分房源）

# %%
print(list(set(df[(df['所在大区']=='湖里')&(df['总价']<200)]['小区名称'].values.tolist())))
# Out:
# ['徐厝社区三航宿舍（昌宾路8—50号）', '中环花园', '加州花园', '大唐五缘yoho', '空港·云立方', '都市华庭', '金岭花园', '永升新城', '一元花园二期', '怡景花园', '德信庄园', '都市阳光', '建邦大厦', '恒丰花园2', '新景园', '金彩花苑', '鹭槟大厦', '象屿大厦', '万华中心', '铭爵山庄', '欣家园', '欣华花园', '海丝艺术品中心', '铁路宿舍小区', '海天路', '嘉福花园', '宏益华府', '龙门天下', '太微花园', '古龙公寓', '都市雅苑', '大唐世家一期', '信达大厦']

# %% [markdown]
# ### 思明区单价3万/平米以内的房源小区名称（小区里面的部分房源）

# %%
print(list(set(df[(df['所在大区']=='思明')&(df['单价']<30000)]['小区名称'].values.tolist())))
# Out:
# ['鼓浪屿内厝澳路', '华星大厦']

# %% [markdown]
# ### 思明区总价200万以内的房源小区名称（小区里面的部分房源）

# %%
print(list(set(df[(df['所在大区']=='思明')&(df['总价']<200)]['小区名称'].values.tolist())))
# Out:
# ['SOHO大厦', '富山花园紫荆苑', '音乐家生活广场', '天宝大厦', '新嘉园', '银龙广场二期', '瑞景商业广场公寓楼', '金辉园', '鼓浪屿内厝澳路', '时尚国际', '长青路', '浦南花园', '一代风华', '裕发广场', '美新广场', '银河大厦', '美仁前社', '能群大厦']

# %% [markdown]
# ### 异常数据说明

# %% [markdown]
# 看小区的名称可以发现，部分小区是大厦的名字，房屋用途实际上是属于商业办公类的，但是原始数据录入的时候，房屋用途标注为普通住宅，数据并没有那么完美。

# %% [markdown]
# ## 总结
# - 厦门二手房源价格总体情况：根据现有的15192套二手房源，均价是39613.9元/平米，单价3万/平米以内的房源只有1/3；平均总价405万，总价在300万以内的房源占比只有41.9%，总价在500万以内的房源占比79.7%，从均价和总价来看，可以说厦门房价非常高。
# - 项目的最后，预算相对没那么多的情况下，给出了一些厦门岛内可选的房源，供参考选择。同样的预算，在岛外选择相对会比较多。

# %% [markdown]
# ## 展望未来

# %% [markdown]
# - 由于数据集里的价格都是在售的二手房源的现价，所以无法分析近几年二手房的价格走势，可以对链家网已成交的房源进行采集，就可以分析出近几年厦门的二手房成交情况和价格变化情况。这是这个项目即将要做的一个补充。
# - 一个城市房价的影响因素有哪些，接下来我们将构建一个简易的模型来预测房价，给模型输入一些特征，比如：区域、面积、房屋户型、户型结构、、是否配备电梯、装修情况等，根据这些特征，模型可以预测出这套房源的总价。这也是这个项目后面要做的另一个补充。
